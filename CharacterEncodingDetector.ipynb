# %% [markdown]
#  # FUNCTION TO DETECT THE CHARACTER ENCODING SCHEME OF A FILE

# %%
def encodingDetector(filepath, increment):
    import charset_normalizer
    import pandas as pd
    increaseby = 500
    while True:
        try:
            with open(filepath, 'rb') as f:
                result = charset_normalizer.detect(f.read(increaseby))
            data = pd.read_csv(filepath, encoding = result['encoding'])
            break
        except UnicodeDecodeError:
            increaseby += increment
    return data

# %% [markdown]
# # TRYING IT OUT

# %%
books = encodingDetector('test data.csv', 500)

# %%
display(books)
# Out:
#        Book Id                                              Title  \
# 0     50617439                                    Louvor da Terra
# 1     11838916  Cat Stories (Everyman's Library Pocket Classic...
# 2     37844623                      The Blood (Jem Flockhart, #3)
# 3    124798505                              Four Seasons in Japan
# 4     24945319  Gone with the Gin: Cocktails with a Hollywood ...
# ..         ...                                                ...
# 401   35606560                            the sun and her flowers
# 402   38591165                                   The Doll Factory
# 403    6275977                                         A Relíquia
# 404      43820                             The Witches' Companion
# 405   50781007  Chinese Fairy Tales and Legends: A Gift Editio...
#
#                    Author             Author l-f     Additional Authors  \
# 0          Byung-Chul Han        Han, Byung-Chul  Miguel Serras Pereira
# 1    Diana Secker Tesdell  Tesdell, Diana Secker                    NaN
# 2            E.S. Thomson          Thomson, E.S.                    NaN
# 3           Nick  Bradley          Bradley, Nick                    NaN
# 4             Tim Federle           Federle, Tim                    NaN
# ..                    ...                    ...                    ...
# 401             Rupi Kaur             Kaur, Rupi                    NaN
# 402     Elizabeth Macneal     Macneal, Elizabeth                    NaN
# 403        Eça de Queirós        Queirós, Eça de                    NaN
# 404    Katherine Ramsland    Ramsland, Katherine              Anne Rice
# 405  Frederick H. Martens  Martens, Frederick H.        Richard Wilhelm
#
#            ISBN        ISBN13  My Rating  Average Rating  \
# 0    9896419884  9.790000e+12          0            3.76
# 1     307700895  9.780000e+12          0            3.56
# 2    1472126572  9.780000e+12          5            4.08
# 3    085752934X  9.780000e+12          0            4.26
# 4     762458607  9.780000e+12          3            4.15
# ..          ...           ...        ...             ...
# 401  1449486797  9.780000e+12          5            4.10
# 402  1529002397  9.780000e+12          5            3.78
# 403  9723808994  9.790000e+12          4            3.74
# 404   345406249  9.780000e+12          0            4.17
# 405  1912392143  9.780000e+12          0            3.47
#
#                      Publisher  ...   Date Read  Date Added  \
# 0      Relógio D'Água Editores  ...         NaN  30/01/2024
# 1           Everyman's Library  ...         NaN  29/01/2024
# 2                    Constable  ...  28/01/2024  18/01/2024
# 3                    Doubleday  ...         NaN   8/12/2023
# 4          Running Press Adult  ...  31/08/2020  31/08/2020
# ..                         ...  ...         ...         ...
# 401  Andrews McMeel Publishing  ...         NaN  16/07/2020
# 402                    Picador  ...         NaN  21/07/2019
# 403   Editora Livros do Brasil  ...  16/07/2020  16/07/2020
# 404           Ballantine Books  ...         NaN  16/01/2022
# 405           Bloomsbury China  ...         NaN  18/01/2023
#
#                                          Bookshelves  \
# 0                                            to-read
# 1    cats, fiction, short-stories, currently-reading
# 2                        historical-fiction, mystery
# 3                                            to-read
# 4                              cookbook, non-fiction
# ..                                               ...
# 401                                           poetry
# 402                                          fiction
# 403                                          fiction
# 404                                          to-read
# 405                                          to-read
#
#                             Bookshelves with positions    Exclusive Shelf  \
# 0                                       to-read (#179)            to-read
# 1    cats (#5), fiction (#35), short-stories (#2), ...  currently-reading
# 2                historical-fiction (#5), mystery (#7)               read
# 3                                       to-read (#178)            to-read
# 4                     cookbook (#3), non-fiction (#19)               read
# ..                                                 ...                ...
# 401                                        poetry (#1)               read
# 402                                       fiction (#5)               read
# 403                                       fiction (#1)               read
# 404                                      to-read (#62)            to-read
# 405                                     to-read (#132)            to-read
#
#                                              My Review Spoiler Private Notes  \
# 0                                                  NaN     NaN           NaN
# 1                                                  NaN     NaN           NaN
# 2                                                  NaN     NaN           NaN
# 3                                                  NaN     NaN           NaN
# 4                                                  NaN     NaN           NaN
# ..                                                 ...     ...           ...
# 401                                                NaN     NaN           NaN
# 402                                                NaN     NaN           NaN
# 403  A Relíquia é mais um dos livros onde Eça de Qu...     NaN           NaN
# 404                                                NaN     NaN           NaN
# 405                                                NaN     NaN           NaN
#
#     Read Count Owned Copies
# 0            0            0
# 1            1            0
# 2            1            0
# 3            0            0
# 4            1            1
# ..         ...          ...
# 401          0            0
# 402          1            0
# 403          1            0
# 404          0            0
# 405          0            1
#
# [406 rows x 24 columns]
